# %% [markdown]
# # ETL Proyect
#
# ### Instructions
#
# * Create a `Vehicles_db` database in pgAdmin 4 then create the following  tables within:
#
#   * A `vehicles` table that contains the data from CSV files(kaggle).
#
#   * A `vehicles_craig` data that we get from scrapping web from Craighlist.

# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### Read  CSV

# %%
vehicles_file = os.path.join("..", "Resources", "vehicles.csv")
vehicles_df = pd.read_csv(vehicles_file)
vehicles_df.head()
# Out:
#            id          region  price  year manufacturer        model  \
# 0  7034441763  salt lake city  17899  2012   volkswagen       golf r
# 1  7034440610  salt lake city      0  2016         ford        f-150
# 2  7034440588  salt lake city  46463  2015          gmc  sierra 1500
# 3  7034440546  salt lake city      0  2016         ford        f-150
# 4  7034406932  salt lake city  49999  2018         ford        f-450
#
#    condition    cylinders    fuel odometer  ...                vin drive  \
# 0  excellent  4 cylinders     gas    63500  ...  WVWPF7AJ6CW316713   4wd
# 1  excellent          NaN     gas       10  ...  1FTMF1EP3GKF13544   4wd
# 2  excellent          NaN     gas     7554  ...  3GTU2WEC6FG228025   4wd
# 3  excellent          NaN     gas       10  ...  1FTEX1EF6GKD25447   4wd
# 4        NaN          NaN  diesel    70150  ...  1FT8W4DT8GEA90427   4wd
#
#       size       type paint_color  \
# 0  compact  hatchback       black
# 1      NaN        NaN         NaN
# 2      NaN        NaN       white
# 3      NaN        NaN         NaN
# 4      NaN     pickup       white
#
#                                          description county state      lat  \
# 0  PRICE REDUCED!   -Garage kept -Low Miles (63K)...    NaN    ut  40.7372
# 1  Drive it home today. Call (Or Text) us now !!C...    NaN    ut  40.5881
# 2  Drive it home today. Call (Or Text) us now !!C...    NaN    ut  40.5881
# 3  Drive it home today. Call (Or Text) us now !!C...    NaN    ut  40.5881
# 4  2018 Ford F-350 F350 F 350 SD Lariat Crew Cab ...    NaN    ut  40.3744
#
#       long
# 0 -111.858
# 1 -111.884
# 2 -111.884
# 3 -111.884
# 4 -104.694
#
# [5 rows x 22 columns]

# %%
### Create a filtered dataframe from specific columns

vehicle_cols = ["id", "region", "year","manufacturer", "model", "paint_color", "state"]
vehicle_transformed= vehicles_df[vehicle_cols].copy()


# Clean the data by dropping duplicates and setting the index

vehicle_transformed.drop_duplicates("id", inplace=True)
vehicle_transformed.set_index("id", inplace=True)

vehicle_transformed.head()
# Out:
#                     region  year manufacturer        model paint_color state
# id
# 7034441763  salt lake city  2012   volkswagen       golf r       black    ut
# 7034440610  salt lake city  2016         ford        f-150         NaN    ut
# 7034440588  salt lake city  2015          gmc  sierra 1500       white    ut
# 7034440546  salt lake city  2016         ford        f-150         NaN    ut
# 7034406932  salt lake city  2018         ford        f-450       white    ut

# %%
manuf = vehicle_transformed.groupby('manufacturer')
total_manuf = manuf['region'].count()
total_manuf_df = pd.DataFrame(total_manuf)
total_manuf_df
# Out:
#                  region
# manufacturer
#  tire rack           18
# acura              4169
# alfa-romeo          109
# aston-martin         22
# audi               5586
# bmw               13468
# buick              6357
# cadillac           7304
# chevrolet         73661
# chrysler           8866
# datsun               68
# dodge             19344
# ferrari              82
# fiat                746
# ford              92601
# gmc               23126
# harley-davidson     215
# hennessey             2
# honda             25585
# hyundai           12182
# infiniti           3933
# jaguar             1029
# jeep              23951
# kia                8821
# land rover           25
# lexus              6292
# lincoln            3393
# mazda              5851
# mercedes-benz     11569
# mercury            1760
# mini               2173
# mitsubishi         2848
# morgan                3
# nissan            26435
# pontiac            3493
# porche               10
# ram               26177
# rover              1840
# saturn             1790
# subaru            10259
# tesla               207
# toyota            38159
# volkswagen        10214
# volvo              3088

# %% [markdown]
# ### URL of page to be scraped

# %%
#Craighlist page
url = 'https://houston.craigslist.org/d/cars-trucks/search/cta?s=240'

# %% [markdown]
# ### Retrieve page with the requests module

# %%
response = requests.get(url)

# %% [markdown]
# ### Create BeautifulSoup object

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Check the results

# %%
print(soup.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    houston cars &amp; trucks  - craigslist
#   </title>
#   <meta content="houston cars &amp; trucks  - craigslist" name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://houston.craigslist.org/search/cta?s=240" rel="canonical"/>
#    <link href="https://houston.craigslist.org/search/cta?format=rss&amp;s=240" rel="alternate" title="RSS feed for craigslist | houston cars &amp; trucks  - craigslist" type="application/rss+xml"/>
#    <link href="https://houston.craigslist.org/search/cta?s=120" rel="prev"/>
#    <link href="https://houston.craigslist.org/search/cta?s=360" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=f45c4074e9853c0ceb280398a8131359" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
#    <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#    <script type="text/javascript">
#     <!--
# var areaCountry = "US";
# var areaID = "23";
# var areaRegion = "TX";
# var catAbb = "cta";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = {"owner":"cto","dealer":"ctd","all":"cta"};
# var searchDistance = null;
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#    </script>
#   </meta>
#  </head>
#  <body class="search has-map">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#      Android
#     </a>
#     <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#      iOS
#     </a>
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/cta" class="breadcrumbs-form" data-action="/search/###/cta" id="breadcrumbform" method="get">
#       <ul class="breadcrumbs">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           houston
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="houston">
#           houston
#          </option>
#          <option value="austin">
#           austin
#          </option>
#          <option value="beaumont">
#           beaumont
#          </option>
#          <option value="cenla">
#           central LA
#          </option>
#          <option value="collegestation">
#           college station
#          </option>
#          <option value="corpuschristi">
#           corpus christi
#          </option>
#          <option value="dallas">
#           dallas
#          </option>
#          <option value="nacogdoches">
#           deep east TX
#          </option>
#          <option value="easttexas">
#           east TX
#          </option>
#          <option value="galveston">
#           galveston
#          </option>
#          <option value="killeen">
#           killeen-temple
#          </option>
#          <option value="lafayette">
#           lafayette
#          </option>
#          <option value="lakecharles">
#           lake charles
#          </option>
#          <option value="sanantonio">
#           san antonio
#          </option>
#          <option value="sanmarcos">
#           san marcos
#          </option>
#          <option value="shreveport">
#           shreveport
#          </option>
#          <option value="victoriatx">
#           victoria, TX
#          </option>
#          <option value="waco">
#           waco
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option selected="" value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="sss">
#           all
#          </option>
#          <option value="ata">
#           antiques
#          </option>
#          <option value="ppa">
#           appliances
#          </option>
#          <option value="ara">
#           arts+crafts
#          </option>
#          <option value="sna">
#           atvs/utvs/snow
#          </option>
#          <option value="pta">
#           auto parts
#          </option>
#          <option value="wta">
#           auto wheels &amp; tires
#          </option>
#          <option value="ava">
#           aviation
#          </option>
#          <option value="baa">
#           baby+kids
#          </option>
#          <option value="bar">
#           barter
#          </option>
#          <option value="haa">
#           beauty+hlth
#          </option>
#          <option value="bip">
#           bike parts
#          </option>
#          <option value="bia">
#           bikes
#          </option>
#          <option value="bpa">
#           boat parts
#          </option>
#          <option value="boo">
#           boats
#          </option>
#          <option value="bka">
#           books
#          </option>
#          <option value="bfa">
#           business
#          </option>
#          <option selected="" value="cta">
#           cars+trucks
#          </option>
#          <option value="ema">
#           cds/dvd/vhs
#          </option>
#          <option value="moa">
#           cell phones
#          </option>
#          <option value="cla">
#           clothes+acc
#          </option>
#          <option value="cba">
#           collectibles
#          </option>
#          <option value="syp">
#           computer parts
#          </option>
#          <option value="sya">
#           computers
#          </option>
#          <option value="ela">
#           electronics
#          </option>
#          <option value="gra">
#           farm+garden
#          </option>
#          <option value="zip">
#           free stuff
#          </option>
#          <option value="fua">
#           furniture
#          </option>
#          <option value="gms">
#           garage sales
#          </option>
#          <option value="foa">
#           general
#          </option>
#          <option value="hva">
#           heavy equipment
#          </option>
#          <option value="hsa">
#           household
#          </option>
#          <option value="jwa">
#           jewelry
#          </option>
#          <option value="maa">
#           materials
#          </option>
#          <option value="mpa">
#           motorcycle parts
#          </option>
#          <option value="mca">
#           motorcycles
#          </option>
#          <option value="msa">
#           music instr
#          </option>
#          <option value="pha">
#           photo+video
#          </option>
#          <option value="rva">
#           RVs
#          </option>
#          <option value="sga">
#           sporting
#          </option>
#          <option value="tia">
#           tickets
#          </option>
#          <option value="tla">
#           tools
#          </option>
#          <option value="taa">
#           toys+games
#          </option>
#          <option value="tra">
#           trailers
#          </option>
#          <option value="vga">
#           video gaming
#          </option>
#          <option value="waa">
#           wanted
#          </option>
#         </select>
#         <span class="no-js">
#          cars+trucks
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb no-js">
#         <input type="submit" value="go"/>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/hou">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="POST">
#         <div class="to-banish-page">
#          <input class="lastLink" name="lastLink" type="hidden" value="//houston.craigslist.org/search/cta?s=240"/>
#          <input class="lastTitle" name="lastTitle" type="hidden" value="houston cars &amp; trucks  - craigslist"/>
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#            0
#           </span>
#           <span class="discards-label">
#            hidden
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       houston            &gt;
#
# cars &amp; trucks
#      </ul>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/cta" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search cars &amp; trucks" type="text" value=""/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fhouston%252Ecraigslist%252Eorg%252Fsearch%252Fcta" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h2 class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </h2>
#      <input id="excats" name="excats" type="hidden"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <div class="cattitle">
#         <a class="reset" href="/search/cta" title="clear all search parameters">
#          cars &amp; trucks
#         </a>
#        </div>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <ul class="searchgroup buttongroup purveyor">
#         <li class="button sel">
#          <a data-val="all" href="/search/cta">
#           all
#          </a>
#         </li>
#         <li class="button">
#          <a data-val="owner" href="/search/cto">
#           owner
#          </a>
#         </li>
#         <li class="button">
#          <a data-val="dealer" href="/search/ctd">
#           dealer
#          </a>
#         </li>
#        </ul>
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas">
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="15">
#             austin, TX
#             <small>
#              (aus)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="199">
#             baton rouge
#             <small>
#              (btr)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="264">
#             beaumont / port arthur
#             <small>
#              (bpt)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="266">
#             brownsville, TX
#             <small>
#              (bro)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="644">
#             central louisiana
#             <small>
#              (aex)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="326">
#             college station, TX
#             <small>
#              (cst)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="265">
#             corpus christi, TX
#             <small>
#              (crp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="21">
#             dallas / fort worth
#             <small>
#              (dal)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="645">
#             deep east texas
#             <small>
#              (och)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="470">
#             galveston, TX
#             <small>
#              (gls)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="643">
#             houma, LA
#             <small>
#              (hum)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="327"/>
#            killeen / temple / ft hood
#            <small>
#             (grk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="283"/>
#            lafayette, LA
#            <small>
#             (lft)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="284"/>
#            lake charles, LA
#            <small>
#             (lkc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="271"/>
#            laredo, TX
#            <small>
#             (lrd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="263"/>
#            mcallen / edinburg
#            <small>
#             (mca)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="563"/>
#            monroe, LA
#            <small>
#             (mlu)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="53"/>
#            san antonio
#            <small>
#             (sat)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="449"/>
#            san marcos, TX
#            <small>
#             (tsu)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="206"/>
#            shreveport, LA
#            <small>
#             (shv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="642"/>
#            southwest MS
#            <small>
#             (hez)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="359"/>
#            texarkana
#            <small>
#             (txk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="649"/>
#            texoma
#            <small>
#             (txm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="308"/>
#            tyler / east TX
#            <small>
#             (etx)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="564"/>
#            victoria, TX
#            <small>
#             (vtx)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="270"/>
#            waco, TX
#            <small>
#             (wco)
#            </small>
#           </label>
#          </li>
#          <li>
#           <span class="nextNearbyZone linklike" data-zone="1">
#            + show
#            <span id="nearbyNumber">
#             26
#            </span>
#            more...
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from zip
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" maxlength="5" name="search_distance" placeholder="miles" size="5" value=""/>
#         <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
#         <span class="icon icon-locate">
#         </span>
#        </div>
#        <div class="searchgroup minmax price">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          make and model
#         </span>
#         <input class="flatinput auto_make_model" data-autocomplete="makemodel" name="auto_make_model" placeholder="make / model" type="text" value="">
#         </input>
#        </div>
#        <div class="searchgroup">
#         <div class="minmax auto_year">
#          <span class="searchfieldlabel">
#           model year
#          </span>
#          <input class="flatinput min" name="min_auto_year" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#          <input class="flatinput max" name="max_auto_year" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#         </div>
#         <div class="minmax auto_miles">
#          <span class="searchfieldlabel">
#           odometer
#          </span>
#          <input class="flatinput min" name="min_auto_miles" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#          <input class="flatinput max" name="max_auto_miles" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#         </div>
#        </div>
#        <div class="searchgroup">
#         <label class="crypto_currency_ok">
#          <input class="autosubmit" name="crypto_currency_ok" type="checkbox" value="1">
#           cryptocurrency ok
#          </input>
#         </label>
#         <br/>
#         <label class="delivery_available">
#          <input class="autosubmit" name="delivery_available" type="checkbox" value="1">
#           delivery available
#          </input>
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup">
#         <div class="search-attribute hide-list" data-attr="language">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           language of posting
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_1" name="language" type="checkbox" value="1">
#              af
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_2" name="language" type="checkbox" value="2">
#              ca
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_3" name="language" type="checkbox" value="3">
#              da
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_4" name="language" type="checkbox" value="4">
#              de
#             </input>
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_5" name="language" type="checkbox" value="5"/>
#             en
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_6" name="language" type="checkbox" value="6"/>
#             es
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_7" name="language" type="checkbox" value="7"/>
#             fi
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_8" name="language" type="checkbox" value="8"/>
#             fr
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_9" name="language" type="checkbox" value="9"/>
#             it
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_10" name="language" type="checkbox" value="10"/>
#             nl
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_11" name="language" type="checkbox" value="11"/>
#             no
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_12" name="language" type="checkbox" value="12"/>
#             pt
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_13" name="language" type="checkbox" value="13"/>
#             sv
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_14" name="language" type="checkbox" value="14"/>
#             tl
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_15" name="language" type="checkbox" value="15"/>
#             tr
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_16" name="language" type="checkbox" value="16"/>
#             zh
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_17" name="language" type="checkbox" value="17"/>
#             ar
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_18" name="language" type="checkbox" value="18"/>
#             ja
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_19" name="language" type="checkbox" value="19"/>
#             ko
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_20" name="language" type="checkbox" value="20"/>
#             ru
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="language_21" name="language" type="checkbox" value="21"/>
#             vi
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="condition">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           condition
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="condition_10" name="condition" type="checkbox" value="10"/>
#             new
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="condition_20" name="condition" type="checkbox" value="20"/>
#             like new
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="condition_30" name="condition" type="checkbox" value="30"/>
#             excellent
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="condition_40" name="condition" type="checkbox" value="40"/>
#             good
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="condition_50" name="condition" type="checkbox" value="50"/>
#             fair
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="condition_60" name="condition" type="checkbox" value="60"/>
#             salvage
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_cylinders">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           cylinders
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_1" name="auto_cylinders" type="checkbox" value="1"/>
#             3 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_2" name="auto_cylinders" type="checkbox" value="2"/>
#             4 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_3" name="auto_cylinders" type="checkbox" value="3"/>
#             5 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_4" name="auto_cylinders" type="checkbox" value="4"/>
#             6 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_5" name="auto_cylinders" type="checkbox" value="5"/>
#             8 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_6" name="auto_cylinders" type="checkbox" value="6"/>
#             10 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_7" name="auto_cylinders" type="checkbox" value="7"/>
#             12 cylinders
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_cylinders_8" name="auto_cylinders" type="checkbox" value="8"/>
#             other
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_drivetrain">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           drive
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_drivetrain_1" name="auto_drivetrain" type="checkbox" value="1"/>
#             fwd
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_drivetrain_2" name="auto_drivetrain" type="checkbox" value="2"/>
#             rwd
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_drivetrain_3" name="auto_drivetrain" type="checkbox" value="3"/>
#             4wd
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_fuel_type">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           fuel
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_fuel_type_1" name="auto_fuel_type" type="checkbox" value="1"/>
#             gas
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_fuel_type_2" name="auto_fuel_type" type="checkbox" value="2"/>
#             diesel
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_fuel_type_3" name="auto_fuel_type" type="checkbox" value="3"/>
#             hybrid
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_fuel_type_4" name="auto_fuel_type" type="checkbox" value="4"/>
#             electric
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_fuel_type_6" name="auto_fuel_type" type="checkbox" value="6"/>
#             other
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_paint">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           paint color
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_1" name="auto_paint" type="checkbox" value="1"/>
#             black
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_2" name="auto_paint" type="checkbox" value="2"/>
#             blue
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_20" name="auto_paint" type="checkbox" value="20"/>
#             brown
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_3" name="auto_paint" type="checkbox" value="3"/>
#             green
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_4" name="auto_paint" type="checkbox" value="4"/>
#             grey
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_5" name="auto_paint" type="checkbox" value="5"/>
#             orange
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_6" name="auto_paint" type="checkbox" value="6"/>
#             purple
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_7" name="auto_paint" type="checkbox" value="7"/>
#             red
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_8" name="auto_paint" type="checkbox" value="8"/>
#             silver
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_9" name="auto_paint" type="checkbox" value="9"/>
#             white
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_10" name="auto_paint" type="checkbox" value="10"/>
#             yellow
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_paint_11" name="auto_paint" type="checkbox" value="11"/>
#             custom
#            </label>
#           </li>
#           <li class="selectall js-only">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_size">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           size
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_size_1" name="auto_size" type="checkbox" value="1"/>
#             compact
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_size_2" name="auto_size" type="checkbox" value="2"/>
#             full-size
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_size_3" name="auto_size" type="checkbox" value="3"/>
#             mid-size
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_size_4" name="auto_size" type="checkbox" value="4"/>
#             sub-compact
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_title_status">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           title status
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_title_status_1" name="auto_title_status" type="checkbox" value="1"/>
#             clean
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_title_status_2" name="auto_title_status" type="checkbox" value="2"/>
#             salvage
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_title_status_3" name="auto_title_status" type="checkbox" value="3"/>
#             rebuilt
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_title_status_4" name="auto_title_status" type="checkbox" value="4"/>
#             parts only
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_title_status_5" name="auto_title_status" type="checkbox" value="5"/>
#             lien
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_title_status_6" name="auto_title_status" type="checkbox" value="6"/>
#             missing
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_transmission">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           transmission
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_transmission_1" name="auto_transmission" type="checkbox" value="1"/>
#             manual
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_transmission_2" name="auto_transmission" type="checkbox" value="2"/>
#             automatic
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_transmission_3" name="auto_transmission" type="checkbox" value="3"/>
#             other
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="auto_bodytype">
#          <div class="title linklike">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           type
#          </div>
#          <ul class="list">
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_1" name="auto_bodytype" type="checkbox" value="1"/>
#             bus
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_2" name="auto_bodytype" type="checkbox" value="2"/>
#             convertible
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_3" name="auto_bodytype" type="checkbox" value="3"/>
#             coupe
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_4" name="auto_bodytype" type="checkbox" value="4"/>
#             hatchback
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_5" name="auto_bodytype" type="checkbox" value="5"/>
#             mini-van
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_6" name="auto_bodytype" type="checkbox" value="6"/>
#             offroad
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_7" name="auto_bodytype" type="checkbox" value="7"/>
#             pickup
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_8" name="auto_bodytype" type="checkbox" value="8"/>
#             sedan
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
#             <input class="multi_checkbox" id="auto_bodytype_9" name="auto_bodytype" type="checkbox" value="9"/>
#             truck
#            </label>
#           </li>
#           <li class="checkbox">
#            <label>
# ...
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7054265062">
#        <a class="result-image gallery" data-ids="1:00V0V_2w9o5AWpEWq,1:01717_f34rLy3X2uX,1:00A0A_fCwGrnFXJoC,1:00m0m_8tN8vjUIpvG,1:00I0I_hBmolj1NkuY,1:00o0o_4fkpGTXm0ls,1:00s0s_lAHk0Geb0XS,1:00G0G_uvqNOXjrPa,1:00909_cLTKwy7HmJ3,1:00a0a_iC2H861wqNc,1:01010_g32rWqa9Fc1,1:00K0K_6cApnxzCO5r,1:00e0e_kJPHjBGAW9D,1:00K0K_3yed8xOXU6o,1:00A0A_kUMaXzAP4K6,1:01212_3daoNwLraof,1:00A0A_7ito0Zshcub,1:00y0y_j1bQvnFyvYc,1:00l0l_1fQYGChpjTp,1:00b0b_bgNemTedCJH,1:01717_41OoNNuGZqg,1:00H0H_1QBC5sq5oJj" href="https://houston.craigslist.org/ctd/d/2017-chevrolet-impala-lt-100-in-house/7054265062.html">
#         <span class="result-price">
#          $2195
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-01-11 14:32" title="Sat 11 Jan 02:32:40 PM">
#          Jan 11
#         </time>
#         <a class="result-title hdrlnk" data-id="7054265062" href="https://houston.craigslist.org/ctd/d/2017-chevrolet-impala-lt-100-in-house/7054265062.html">
#          2017 CHEVROLET IMPALA LT  100% IN-HOUSE FINANCING - BUY HERE PAY HERE
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $2195
#          </span>
#          <span class="result-hood">
#           (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7054265014" data-repost-of="7042193901">
#        <a class="result-image gallery" data-ids="1:00X0X_9YRA0fxUnFv,1:00i0i_4oSlI4EWmJq,1:00303_kzkaF0vc6fP,1:00o0o_dvurkcZhlXu,1:01414_4R128o78Iio,1:00p0p_3GGE8vmiJMB,1:00v0v_bWYiHrKyW33,1:00404_4s2NNeYtGNl,1:00000_woVElwUuOU,1:01414_bW1gaLzy3iA,1:00L0L_gcwJIVNfa5p,1:00707_VGL36jdxIc,1:00O0O_jka0ihN1pxs,1:00S0S_lBWgw919rnK,1:00t0t_jkS6hPu7zdj,1:00l0l_kVMLH4iAqZk,1:00X0X_leyc4ZzkJz6,1:00I0I_e9fyv82E2pT,1:00U0U_cfwYZ2FTmXJ,1:00e0e_8mKbbv3Yg16,1:00G0G_eOEjhiKmZSf,1:00F0F_JsAGoIq5FD,1:01111_a4dXoQVMKUW,1:00o0o_bTFKPCjWt7E" href="https://houston.craigslist.org/cto/d/spring-2013-ford-f350-super-duty-turbo/7054265014.html">
#         <span class="result-price">
#          $17850
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-01-11 14:32" title="Sat 11 Jan 02:32:34 PM">
#          Jan 11
#         </time>
#         <a class="result-title hdrlnk" data-id="7054265014" href="https://houston.craigslist.org/cto/d/spring-2013-ford-f350-super-duty-turbo/7054265014.html">
#          2013 FORD F350 SUPER DUTY TURBO DIESEL CREWCAB LONGBED WELL MAINTAINED
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $17850
#          </span>
#          <span class="result-hood">
#           (WOODLANDS)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7054264215">
#        <a class="result-image gallery" data-ids="1:00606_j0FL3u2BSvl,1:00x0x_c67y3v6sL3v,1:00B0B_2c0me5wUy3s,1:00t0t_dZzblgaVoWL,1:00P0P_lUq5l9UkNgw,1:00606_61lzFCS7iDn,1:00F0F_4pjUFW38V61,1:00P0P_LQLSpQRAci,1:01515_6PuPyceOtEp,1:00n0n_63qDTygEcBZ,1:00g0g_8Q5CVmPLyE7,1:00606_4T5Pkhs4Oxs,1:00J0J_ecADsl5sm5T,1:01717_7L4KcrVoyxq,1:01010_8HLaKQO223i,1:00303_iGAy43bzKx5,1:01111_8jEVkEn5VjG,1:00l0l_b13S0CIzyPe,1:01313_fIWmfBT0Ej2,1:01212_98PK012WTxM,1:00j0j_ibGRrAtJy2S,1:00n0n_4oavpiarZGi,1:00606_iNLWWhh8BvX,1:00000_3nk1LvJWREo" href="https://houston.craigslist.org/ctd/d/webster-2017-honda-civic-sport-cvt/7054264215.html">
#         <span class="result-price">
#          $17788
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-01-11 14:31" title="Sat 11 Jan 02:31:20 PM">
#          Jan 11
#         </time>
#         <a class="result-title hdrlnk" data-id="7054264215" href="https://houston.craigslist.org/ctd/d/webster-2017-honda-civic-sport-cvt/7054264215.html">
#          *2017* *Honda* *Civic* *Sport CVT Hatchback*
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $17788
#          </span>
#          <span class="result-hood">
#           (_Honda_ _Civic_ _Sedan_)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup">
#       <span class="resulttotal">
#        <span class="for-map">
#         displaying
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/cta" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/cta?s=120" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           241
#          </span>
#          -
#          <span class="rangeTo">
#           360
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/cta?s=360" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <aside class="tsb">
#     <ul>
#      <li>
#       <a href="https://www.craigslist.org/about/safety">
#        safety tips
#       </a>
#       <li>
#        <a href="https://www.craigslist.org/about/prohibited">
#         prohibited items
#        </a>
#        <li>
#         <a href="https://www.craigslist.org/about/recalled_items">
#          product recalls
#         </a>
#         <li>
#          <a href="https://www.craigslist.org/about/scams">
#           avoiding scams
#          </a>
#         </li>
#        </li>
#       </li>
#      </li>
#     </ul>
#    </aside>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://houston.craigslist.org/search/cta?format=rss&amp;s=240">
#       RSS
#      </a>
#      <a href="https://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br/>
#     </span>
#     <ul class="clfooter">
#      <li>
#       ©
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use.en-us">
#        terms
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script>
#    try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
#   </script>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=e9ae037676b2885c7a77adfdf33f8501" type="text/javascript">
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=34556d4d2e18087b28df012cc48ea196" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=30665e23846bcb69ae24b2b76bc99ad1" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/postings-concat.min.js?v=5da8d5d0efb2e814fc9b7cf2a309d6d1" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Results in a List

# %%
results = soup.find_all('li', class_="result-row")
print(len(results))
# Out:
# 120

# %%
print(results[0].prettify())
# Out:
# <li class="result-row" data-pid="7054325181">
#  <a class="result-image gallery" data-ids="1:00505_aipgiZABB5v,1:00z0z_laLGnfqCvon,1:00V0V_9HSPF2AZepG,1:00101_abT80UbDtY0,1:00B0B_6U5kYuXL6Ll,1:00202_blhs7Tl9IS0,1:00909_i8w2N9CB76L,1:00Y0Y_8XcxQ4pyBSi,1:00707_8gWXhToo9rz,1:00q0q_hJAz10FuGxj,1:00A0A_vQi563bAfG,1:00101_gkNTnKCFeU4,1:00u0u_6Mn9dls0Hys,1:00m0m_3HSLpsHiTqv,1:00n0n_bfaoQGkoLPE,1:00F0F_lFnzThjbdCK,1:00t0t_anieZf8vHD0,1:00303_dsEOnvrmOtr,1:00V0V_4ouAHYD4oNB,1:01414_2hZ7F6uE4I3,1:00l0l_eC8vTddf4L0,1:00X0X_T3RqqgAAsr" href="https://houston.craigslist.org/cto/d/north-houston-2004-dodge-ram-pickup/7054325181.html">
#   <span class="result-price">
#    $11980
#   </span>
#  </a>
#  <p class="result-info">
#   <span class="icon icon-star" role="button">
#    <span class="screen-reader-text">
#     favorite this post
#    </span>
#   </span>
#   <time class="result-date" datetime="2020-01-11 16:01" title="Sat 11 Jan 04:01:01 PM">
#    Jan 11
#   </time>
#   <a class="result-title hdrlnk" data-id="7054325181" href="https://houston.craigslist.org/cto/d/north-houston-2004-dodge-ram-pickup/7054325181.html">
#    2004 Dodge Ram Pickup 2500 SLT 4dr Quad Cab Rwd SB
#   </a>
#   <span class="result-meta">
#    <span class="result-price">
#     $11980
#    </span>
#    <span class="result-tags">
#     <span class="pictag">
#      pic
#     </span>
#    </span>
#    <span class="banish icon icon-trash" role="button">
#     <span class="screen-reader-text">
#      hide this posting
#     </span>
#    </span>
#    <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#    </span>
#    <a class="restore-link" href="#">
#     <span class="restore-narrow-text">
#      restore
#     </span>
#     <span class="restore-wide-text">
#      restore this posting
#     </span>
#    </a>
#   </span>
#  </p>
# </li>

# %% [markdown]
# ### Loop the results

# %%
title_ls = []
price_ls = []
hood_ls = []
link_ls = []


for result in results:
    
    # Error handling
    try:
        
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        
        # Identify and return price of listing
        price = result.find('span', class_="result-price").text
        
        hood = result.find('span', class_= "result-hood").text        
      
    
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and hood and link):
            print('-------------')
            print(title)
            title_ls.append(title)
            print(price)
            price_ls.append(price)
            print(hood)
            hood_ls.append(hood)
            print(link)
            link_ls.append(link)
            
    except AttributeError as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# -------------
# 2017 FORD FOCUS SE
# $6900
#  (richmond)
# https://houston.craigslist.org/cto/d/richmond-2017-ford-focus-se/7054324938.html
# -------------
# 2013 *Jeep* *Wrangler* *Rubicon* Commando Green
# $27997
#  (Emmons Motor Company)
# https://houston.craigslist.org/ctd/d/south-houston-2013-jeep-wrangler/7054324640.html
# -------------
# 2005 BLUE BIRD ALL AMERICAN  CUMMINS 8.3 250HP
# $6500
#  (N Houston)
# https://houston.craigslist.org/cto/d/houston-2005-blue-bird-all-american/7054323708.html
# 'NoneType' object has no attribute 'text'
# -------------
# Hyundai Sonata
# $3000
#  (West Houston)
# https://houston.craigslist.org/cto/d/houston-hyundai-sonata/7054322916.html
# -------------
# 2015 HONDA ACCORD SPORT  100% IN-HOUSE FINANCING - BUY HERE PAY HERE
# $1495
#  (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
# https://houston.craigslist.org/ctd/d/2015-honda-accord-sport-100-in-house/7054322402.html
# -------------
# 2013 Ford Explorer
# $7300
#  (Southwest Houston)
# https://houston.craigslist.org/cto/d/houston-2013-ford-explorer/7054321598.html
# -------------
# 1993 Mercedes-Benz 190E 2.3 Low Mile California Car XLNT
# $5500
#  (Galleria Area)
# https://houston.craigslist.org/cto/d/houston-1993-mercedes-benz-190e-23-low/7054321202.html
# -------------
# 2012 TOYOTA SEQUOIA PLATINUM
# $14995
#  (+ Houston Used Auto Sales)
# https://houston.craigslist.org/ctd/d/houston-2012-toyota-sequoia-platinum/7054321110.html
# -------------
# 2013 Jeep Wrangler 4x4
# $7900
#  (Southwest Houston)
# https://houston.craigslist.org/cto/d/houston-2013-jeep-wrangler-4x4/7054320954.html
# -------------
# 2014 BMW M6 Base 2dr Convertible
# $33491
#  (Houston)
# https://houston.craigslist.org/ctd/d/houston-2014-bmw-m6-base-2dr-convertible/7054320437.html
# -------------
# 2011 Toyota Camry
# $4500
#  (Southwest Houston)
# https://houston.craigslist.org/cto/d/stafford-2011-toyota-camry/7054320282.html
# -------------
# 2012 GMC YUKON XL 1500 SLT  100% IN-HOUSE FINANCING - BUY HERE PAY HERE
# $1795
#  (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
# https://houston.craigslist.org/ctd/d/2012-gmc-yukon-xl-1500-slt-100-in-house/7054318624.html
# $5900
#  (sw houston)
# https://houston.craigslist.org/cto/d/houston-2012-chevrolet-traverse-ls/7054273988.html
# -------------
# 2014 CHEVROLET SUBURBAN 1500 LT  100% IN-HOUSE FINANCING - BUY HERE PAY HERE
# $2495
#  (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
# https://houston.craigslist.org/ctd/d/2014-chevrolet-suburban-1500-lt-100-in/7054273486.html
# -------------
# 2011 Honda Pilot EX-L
# $8300
#  (Katy)
# https://houston.craigslist.org/cto/d/katy-2011-honda-pilot-ex/7054272210.html
# -------------
# 2007 Ford Expedition Limited *Fully Loaded* *$7,500 OBO*
# $7500
#  (Spring)
# https://houston.craigslist.org/ctd/d/spring-2007-ford-expedition-limited/7054272116.html
# -------------
# 2006 HONDA RIDGELINE RTL 4X4
# $6995
#  (HOUSTON)
# https://houston.craigslist.org/ctd/d/houston-2006-honda-ridgeline-rtl-4x4/7054272118.html
# -------------
# Built Turbo Miata 1999 -  300+WHP
# $12500
#  (Houston, TX)
# https://houston.craigslist.org/cto/d/sugar-land-built-turbo-miata-whp/7054271831.html
# 'NoneType' object has no attribute 'text'
# -------------
# 2015 Silver Volkswagen Passat Wolfsburg Edition, 4 Door, 1.8L Turbo
# $8900
#  (Houston Heights)
# https://houston.craigslist.org/cto/d/houston-2015-silver-volkswagen-passat/7054271649.html
# -------------
# 2004 FORD F350 lariat
# $8900
#  (Beechnut & 59)
# https://houston.craigslist.org/cto/d/houston-2004-ford-f350-lariat/7054271171.html
# -------------
# 2010 NISSAN TITAN
# $5900
#  (Beechnut & 59)
# https://houston.craigslist.org/cto/d/houston-2010-nissan-titan/7054270652.html
# -------------
# 2005 LEXUS RX 330
# $5500
#  (Beechnut & 59)
# https://houston.craigslist.org/cto/d/houston-2005-lexus-rx-330/7054270234.html
# -------------
# **2011 CHEVROLET SILVERADO LT **TEXAS  EDITION PACKAGE **OFF ROAD PACK
# $12895
#  (!!899 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/2011-chevrolet-silverado-lt-texas/7054269599.html
# -------------
# 2007 HONDA ODYSSEY EX-L, V6, Low miles, clean title, single owner
# $7500
#  (Missouri city)
# https://houston.craigslist.org/cto/d/missouri-city-2007-honda-odyssey-ex-v6/7054269212.html
# -------------
# 2014 CHEVROLET SUBURBAN 1500  LS  100% IN-HOUSE FINANCING - BUY HERE PAY HERE
# $2195
#  (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
# https://houston.craigslist.org/ctd/d/2014-chevrolet-suburban-1500-ls-100-in/7054269206.html
# -------------
# **2008 CHEVROLET SILVERADO LS 2500 HD**LONG BED 6.6 DURAMAX DIESEL 4X4
# $0
#  (1495 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/houston-2008-chevrolet-silverado-ls/7054268584.html
# -------------
# ***2011 GMC SIERRA 2500 SLT **DURAMAX 6.6 DIESEL 4X4*LEATHER*WE FINANC
# $0
#  (!!2495 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/2011-gmc-sierra-2500-slt-duramax-66/7054267971.html
# -------------
# ***2018 DODGE RAM 2500 SLT CUMMINS DIESEL 6.7 BIG HORN PACKAGE*4X4
# $0
#  (!!1895 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/2018-dodge-ram-2500-slt-cummins-diesel/7054267534.html
# -------------
# ***2017 DODGE RAM 3500 CUMMINS DIESEL 6.7 4X4*CLEAN TITLE*LIKE NEW*
# $0
#  (!!1895 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/2017-dodge-ram-3500-cummins-diesel-67/7054267018.html
# -------------
# *2012 JEEP GRAND CHEROKEE SRT8*SUPER SPORT*TUNED INJEN**BORLA EXHAUST*
# $0
#  (!!1495 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/2012-jeep-grand-cherokee-srt8super/7054266502.html
# -------------
# 2005 Acura RL
# $1600
#  (Houston)
# https://houston.craigslist.org/cto/d/humble-2005-acura-rl/7054266301.html
# -------------
# 2010 Dodge Ram Mega Cab 3500
# $27000
#  (Conroe)
# https://houston.craigslist.org/cto/d/conroe-2010-dodge-ram-mega-cab-3500/7054266283.html
# -------------
# 1967 Ford Mustang Convertible GTA Clone
# $20000
#  (League City)
# https://houston.craigslist.org/cto/d/kemah-1967-ford-mustang-convertible-gta/7054266080.html
# -------------
# 2003 Dodge Ram 1500 SLT Quad Cab pickup/one owner
# $4975
#  (Conroe, TX)
# https://houston.craigslist.org/ctd/d/conroe-2003-dodge-ram-1500-slt-quad-cab/7054265865.html
# -------------
# ***2012 FORD F250 LARIAT 4X4**FX4 PACKAGE **LEATHER*HEATHER*WE FINANCE
# $0
#  (1895 DOWN PAYMENT !!wac.!!WWW.SUGARLANDAUTOFINANCE.COM)
# https://houston.craigslist.org/ctd/d/houston-2012-ford-f250-lariat-4x4fx4/7054265828.html
# -------------
# 2017 CHEVROLET IMPALA LT  100% IN-HOUSE FINANCING - BUY HERE PAY HERE
# $2195
#  (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
# https://houston.craigslist.org/ctd/d/2017-chevrolet-impala-lt-100-in-house/7054265062.html
# -------------
# 2013 FORD F350 SUPER DUTY TURBO DIESEL CREWCAB LONGBED WELL MAINTAINED
# $17850
#  (WOODLANDS)
# https://houston.craigslist.org/cto/d/spring-2013-ford-f350-super-duty-turbo/7054265014.html
# -------------
# *2017* *Honda* *Civic* *Sport CVT Hatchback*
# $17788
#  (_Honda_ _Civic_ _Sedan_)
# https://houston.craigslist.org/ctd/d/webster-2017-honda-civic-sport-cvt/7054264215.html

# %%
# Merge list
ziplist = list(zip(title_ls, price_ls, hood_ls, link_ls))

# %%
# Create Date frame
vehicles_craig = pd.DataFrame(ziplist, columns = ['Title', 'Price','Neighborhood', 'Link'])

vehicles_craig.head()
# Out:
#                                                Title   Price  \
# 0                                 2017 FORD FOCUS SE   $6900
# 1    2013 *Jeep* *Wrangler* *Rubicon* Commando Green  $27997
# 2     2005 BLUE BIRD ALL AMERICAN  CUMMINS 8.3 250HP   $6500
# 3                                     Hyundai Sonata   $3000
# 4  2015 HONDA ACCORD SPORT  100% IN-HOUSE FINANCI...   $1495
#
#                                        Neighborhood  \
# 0                                        (richmond)
# 1                            (Emmons Motor Company)
# 2                                       (N Houston)
# 3                                    (West Houston)
# 4   (DOWN ** WE SPECIALZED WITH IN HOUSE FINANCING)
#
#                                                 Link
# 0  https://houston.craigslist.org/cto/d/richmond-...
# 1  https://houston.craigslist.org/ctd/d/south-hou...
# 2  https://houston.craigslist.org/cto/d/houston-2...
# 3  https://houston.craigslist.org/cto/d/houston-h...
# 4  https://houston.craigslist.org/ctd/d/2015-hond...

# %% [markdown]
# ### Create database connection

# %%
pg_user = 'postgres'
pg_password = 'luar6902'
db_name = 'Vehicles_db'

connection_string = f"{pg_user}:{pg_password}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ### Confirm tables

# %%
engine.table_names()
# Out:
# ['vehicles', 'vehicles_craig']

# %% [markdown]
# ### Load DataFrames into database

# %%
vehicle_transformed.to_sql(name='vehicles', con=engine, if_exists='append', index=True)

# %%
vehicles_craig.to_sql(name = 'vehicles_craig', con = engine, if_exists='append', index=True)

# %%
pd.read_sql_query('select * from vehicles', con=engine).head()
# Out:
#            id          region    year manufacturer        model paint_color  \
# 0  7034441763  salt lake city  2012.0   volkswagen       golf r       black
# 1  7034440610  salt lake city  2016.0         ford        f-150        None
# 2  7034440588  salt lake city  2015.0          gmc  sierra 1500       white
# 3  7034440546  salt lake city  2016.0         ford        f-150        None
# 4  7034406932  salt lake city  2018.0         ford        f-450       white
#
#   state
# 0    ut
# 1    ut
# 2    ut
# 3    ut
# 4    ut

# %%
pd.read_sql_query('select * from vehicles_craig', con=engine).head()
# Out:
#    index                                              Title   Price  \
# 0      0            2006 Toyota 4Runner SR5 4WD 4dr SUV 4x4   $7285
# 1      1                               2007 f150 king ranch   $6899
# 2      2  TOYOTA TUNDRA SR5--2015--REVCAM NAVI CREWMAX C...  $18900
# 3      3  CHEVROLET SILVERADO LT Texas EDT--2014--Naviga...  $16900
# 4      4                                     2006 Dodge Ram   $1300
#
#                                 Neighborhood  \
# 0                                  (Houston)
# 1                                   (Spring)
# 2   (A/F WE FINANCE)(CALL DEXTER 3462298640)
# 3   (A/F WE FINANCE)(CALL DEXTER 3462298640)
# 4                                  (HOUSTON)
#
#                                                 Link
# 0  https://houston.craigslist.org/ctd/d/houston-2...
# 1  https://houston.craigslist.org/cto/d/spring-20...
# 2  https://houston.craigslist.org/ctd/d/houston-t...
# 3  https://houston.craigslist.org/ctd/d/houston-c...
# 4  https://houston.craigslist.org/cto/d/houston-2...
